# %% [markdown]
# # Feature extraction
#
# In this notebook we will use the VGG16 network pre-trained on ImageNet to compute meaningful numeric descriptions
#
# of the contents of each image. We will use these later to classify the images with K-means.

# %% [markdown]
# ## Module imports
#
# We will use keras to access the VGG16 network.

# %%
import numpy as np
import os
from pathlib import Path
import pickle
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input

import sys
sys.path.append('..')
from helper.classification_tools import CustomLabelEncoder
# Out:
# 2025-01-28 12:07:02.573988: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-28 12:07:02.737496: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738055222.801779    7056 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738055222.820844    7056 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-28 12:07:02.974348: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Loading files
# First, we need to get the file paths of the pre-processed images we saved in 01_preprocess.ipynb.

# %%
img_root = Path('..','data','images_preprocessed','images_histeq_resize')  # directory where images are stored.
assert img_root.is_dir() # make sure directory exists and is properly found
files = sorted(img_root.glob("*.bmp"))  # returns a list of all of the images in the directory, sorted by filename.

## Shuffle the filenames so they appear randomly in the dataset. 
rs = np.random.RandomState(seed=749976)
rs.shuffle(files)

assert len(files) == 1500  # make sure all files are found.
print('first 10 filenames: {}'.format([x.name for x in files[:10]]))
# Out:
# first 10 filenames: ['Sc_68.bmp', 'Cr_152.bmp', 'PS_298.bmp', 'Pa_216.bmp', 'PS_255.bmp', 'Sc_185.bmp', 'RS_95.bmp', 'Pa_125.bmp', 'RS_263.bmp', 'PS_169.bmp']

# %% [markdown]
# ## Extracting the labels from filenames
# The labels are determined from the characteris in the filename before the first "_".
#
# We could also just take the first two characters of the filename, but this does not generalize to cases where the labels have different numbers of characters.

# %%
def extract_labels(f): return [x.stem.split('_')[0] for x in f]
labels = extract_labels(files)
print('first 10 labels: {}'.format(labels[:10]))
# Out:
# first 10 labels: ['Sc', 'Cr', 'PS', 'Pa', 'PS', 'Sc', 'RS', 'Pa', 'RS', 'PS']

# %% [markdown]
# ## Label encoding
# One step that will make our lives easier throughout the analysis is standardizing the
# encoding of labels. The labels are stored as strings in the filenames, but it will be more
# convenient to convert them to numeric values for more convenient calculations of statistics like accuracy, precision, recall, etc.
# We can create one LabelEncoder model and save it for reuse throughout the project.
#
# sklearn has a LabelEncoder object, but it doesn't let you sort the labels alphabetically. Therefore I use a simple label encoder which can do this.

# %%
le = CustomLabelEncoder()
le.fit(labels, sorter=lambda x: x.upper())

labels_int = le.transform(labels[:10])
labels_str = le.inverse_transform(labels_int)

# save the label encoder so it can be used throughout the rest of this project
with open(Path('..','models','label_encoder.pickle'), 'wb') as f:
    pickle.dump(le, f)

print('label encodings: {}'.format(le.mapper))
print('first 10 integer labels: {}'.format(labels_int))
print('first 10 string labels: {}'.format(labels_str))
# Out:
# label encodings: {np.str_('Cr'): 0, np.str_('Pa'): 1, np.str_('PS'): 2, np.str_('RS'): 3, np.str_('Sc'): 4}
# first 10 integer labels: [4 0 2 1 2 4 3 1 3 2]
# first 10 string labels: ['Sc' 'Cr' 'PS' 'Pa' 'PS' 'Sc' 'RS' 'Pa' 'RS' 'PS']

# %% [markdown]
# ## Loading Images
# For feature extraction to work correctly, the images have to be in the correct format for the network weights.
# Keras gives us functions for loading and formatting these images. Note the function is called 'preprocessing,'
# but it does not actually change the properties of the image like the preprocessing we did before. Instead, it
# ensures that the images are represented the correct way.

# %%
def load_images(paths):
    """
    Loads images in the correct format for use with the Keras VGG16 model
    
    Images are loaded as PIL image objects, converted to numpy array, and then formatted
    with the appropriate VGG16.preprocess_input() function. Note that this only changes
    how the images are represented, it does not change the actual visual properties of the
    images like preprocessing did before.
    
    Parameters
    ----------
    paths: list(Path)
        list of Paths to each file where the image is stored. Note that the images should 
        have the same height, width in pixels so they can be stored in one array.
    
    Returns
    ----------
    images: ndarray
        n_images x r x c x 3 array of pixel values that is compatible with the Keras model.
    
    """
    
    images = [image.load_img(file) for file in paths] # load images
    # convert images to an array with shape consistent for the vgg16 input
    images = np.asarray([image.img_to_array(img) for img in images]) 
    # normalizes the pixel values to match the imagenet format (and therefore the pre-trained weights)
    images = preprocess_input(images) 
    
    return images

# %%
images = load_images(files)
assert len(images) == 1500
print(images.shape)
# Out:
# (1500, 224, 224, 3)

# %% [markdown]
# # Feature extraction
# We will use the VGG16 network as a signal processor, generating a feature descriptor for each image that we can use later for classification.

# %% [markdown]
# Get the weights of the VGG16 model

# %%
vgg16_path = Path('..','models','VGG16.h5')
if not vgg16_path.is_file():
    vgg16 = keras.applications.VGG16(include_top=True,  # include fully connected layers
                                     weights='imagenet') # use pre-trained model
    vgg16.save(vgg16_path) # save model so we don't have to download it everytime
    
else:   
    vgg16 = keras.models.load_model(vgg16_path) # use saved model
# Out:
# I0000 00:00:1738055265.221977    7056 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5676 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# The warning indicates that the model hasn't been compiled with an optimizer/loss function for training. Since we are
# not training the model, and are just using it as a feature extractor, this is not a problem.

# %% [markdown]
# We can see the strutcure of the VGG16 model here.

# %%
vgg16.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 1000)           │     4,097,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 138,357,544 (527.79 MB)
#  Trainable params: 138,357,544 (527.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The pre-trained model will run data through the entire network and return the output of the classification layer.
#
# Howevever, we only want the output of the intermediate layer so that we can use it as a feature descriptor.
#
# By default, we will use the fc1 (first fully-connected layer), but we will use other layers as well in the sensitivity analysis.

# %%
def layer_extractor(model=vgg16, layer='fc1'):
    """
    returns a model that will extract the outputs of *layer* from *model*.
    
    Parameters
    -------------
    model: keras model
        full model from which intermediate layer will be extracted
    layer: string
        name of layer from which to extract outputs
    
    Returns
    -------------
    new_model: keras model
        feature extractor model which takes the same inputs as *model* and returns the outputs
        of the intermediate layer specified by *layer* by calling new_model.predict(inputs)
    """
    assert layer in [x.name for x in model.layers]  # make sure the layer exists

    new_model = keras.Model(inputs = vgg16.input, outputs=[vgg16.get_layer(layer).output])
    
    return new_model

# %% [markdown]
# ## FC1 features
#
# This extracts the features, and then saves them to the target directory, along with the filenames and extracted labels.

# %%
fc1_extractor = layer_extractor()
fc1 = fc1_extractor.predict(images, verbose=True)

# save results
results = {'filename' : files,
           'features': fc1,
          'labels': labels,
           'layer_name': 'fc1'
          }

feature_dir = Path('..','data','features')
os.makedirs(feature_dir, exist_ok=True)
with open(feature_dir / 'VGG16_fc1_features_std.pickle', 'wb') as f:
    pickle.dump(results, f)

print(fc1.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738055303.636253   34263 service.cc:148] XLA service 0x710684003010 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738055303.636538   34263 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-01-28 12:08:23.647975: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1738055303.688940   34263 cuda_dnn.cc:529] Loaded cuDNN version 90700
# 2025-01-28 12:08:26.540726: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  1/47 ━━━━━━━━━━━━━━━━━━━━ 10:08 13s/step
# I0000 00:00:1738055316.654611   34263 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 31s 390ms/step
# (1500, 4096)

# %%
# import pandas as pd

# obj = pd.read_pickle('../data/features/VGG16_fc1_features_std.pickle')
# print (obj)
# Out:
# {'filename': [PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_68.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Cr_152.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_298.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_216.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_255.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_185.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_95.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_125.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_263.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_169.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_179.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_155.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_142.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_292.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_214.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_19.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_239.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_76.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_168.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_191.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_90.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_64.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_92.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_46.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_232.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_297.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_281.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_217.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_225.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_237.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_183.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_67.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Cr_67.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_207.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_16.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_212.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_170.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_264.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_29.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_74.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_72.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_238.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Cr_140.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_215.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Sc_276.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_64.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_237.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_283.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_8.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_104.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/PS_195.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_120.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/Pa_48.bmp'), PosixPath('../data/images_preprocessed/images_histeq_resize/RS_66.bmp'), PosixPath ...
#         0.        ],
#        [0.        , 2.7532244 , 0.        , ..., 0.789832  , 1.5307237 ,
#         0.        ],
#        [0.        , 2.136097  , 0.        , ..., 0.18768613, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 2.33887   , 0.        , ..., 0.        , 3.805818  ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.3418608 ,
#         0.        ],
#        [0.        , 1.58727   , 0.        , ..., 1.8375341 , 0.        ,
#         0.        ]], dtype=float32), 'labels': ['Sc', 'Cr', 'PS', 'Pa', 'PS', 'Sc', 'RS', 'Pa', 'RS', 'PS', 'PS', 'Pa', 'RS', 'Pa', 'PS', 'Pa', 'PS', 'Sc', 'Pa', 'Sc', 'PS', 'RS', 'Pa', 'Pa', 'Sc', 'PS', 'Sc', 'Sc', 'Sc', 'Pa', 'Pa', 'PS', 'Cr', 'RS', 'Sc', 'Pa', 'RS', 'Sc', 'RS', 'RS', 'Pa', 'RS', 'Cr', 'PS', 'Sc', 'Pa', 'RS', 'RS', 'RS', 'PS', 'PS', 'Pa', 'Pa', 'RS', 'Cr', 'RS', 'Cr', 'RS', 'Sc', 'Pa', 'PS', 'RS', 'PS', 'Cr', 'Cr', 'Cr', 'Sc', 'PS', 'Cr', 'PS', 'PS', 'Pa', 'PS', 'Sc', 'Pa', 'Pa', 'Sc', 'RS', 'RS', 'RS', 'Sc', 'PS', 'Pa', 'Cr', 'PS', 'PS', 'Cr', 'Pa', 'RS', 'Cr', 'RS', 'PS', 'PS', 'PS', 'Pa', 'Sc', 'Pa', 'PS', 'Sc', 'Cr', 'RS', 'Pa', 'Pa', 'RS', 'Cr', 'RS', 'PS', 'RS', 'Sc', 'PS', 'Cr', 'Sc', 'PS', 'RS', 'Cr', 'Pa', 'PS', 'Pa', 'Sc', 'RS', 'Pa', 'Pa', 'Cr', 'Cr', 'Pa', 'RS', 'Pa', 'Pa', 'PS', 'PS', 'Sc', 'PS', 'RS', 'RS', 'PS', 'RS', 'Cr', 'Pa', 'Sc', 'RS', 'PS', 'RS', 'PS', 'PS', 'PS', 'Cr', 'RS', 'Pa', 'PS', 'Cr', 'Pa', 'RS', 'RS', 'Pa', 'Cr', 'Pa', 'PS', 'Cr', 'PS', 'Pa', 'RS', 'Cr', 'Cr', 'RS', 'Cr', 'PS', 'Sc', 'Sc', 'RS', 'Cr', 'RS', 'Pa', 'Pa', 'Cr', 'Sc', 'Sc', 'Sc', 'Cr', 'Cr', 'RS', 'Pa', 'Pa', 'RS', 'PS', 'RS', 'Pa', 'PS', 'RS', 'Cr', 'Pa', 'Cr', 'RS', 'Pa', 'Cr', 'PS', 'RS', 'PS', 'Sc', 'Cr', 'RS', 'Cr', 'RS', 'RS', 'Sc', 'PS', 'RS', 'Sc', 'Pa', 'Sc', 'RS', 'Sc', 'PS', 'Pa', 'RS', 'PS', 'PS', 'Cr', 'RS', 'Pa', 'Sc', 'RS', 'Pa', 'PS', 'Pa', 'Cr', 'Sc', 'Sc', 'RS', 'Cr', 'Cr', 'PS', 'Cr', 'Cr', 'PS', 'PS', 'Pa', 'Cr', 'RS', 'RS', 'PS', 'Sc', 'Cr', 'RS', 'Sc', 'Pa', 'RS', 'Sc', 'Cr', 'Sc', 'Cr', 'Pa', 'RS', 'Cr', 'PS', 'RS', 'Sc', 'Cr', 'Sc', 'Pa', 'Sc', 'Cr', 'Sc', 'RS', 'Sc', 'RS', 'Sc', 'Cr', 'Cr', 'RS', 'Sc', 'Pa', 'Sc', 'Pa', 'Sc', 'PS', 'Sc', 'Pa', 'PS', 'PS', 'Sc', 'PS', 'RS', 'Sc', 'RS', 'Pa', 'RS', 'RS', 'Pa', 'RS', 'Pa', 'RS', 'Pa', 'PS', 'Cr', 'PS', 'PS', 'PS', 'Sc', 'RS', 'RS', 'PS', 'RS', 'PS', 'RS', 'Sc', 'Pa', 'PS', 'Pa', 'Sc', 'Sc', 'Cr', 'PS', 'PS', 'Pa', 'PS', 'Cr', 'RS', 'Sc', 'RS', 'Sc', 'Pa', 'RS', 'Sc', 'Pa', 'PS', 'Sc', 'Cr', 'RS', 'RS', 'Pa', 'PS', 'Pa', 'RS', 'Sc', 'Sc', 'Sc', 'Sc', 'PS', 'Pa', 'RS', 'Pa', 'Pa', 'RS', 'PS', 'PS', 'PS', 'RS', 'RS', 'Cr', 'RS', 'Pa', 'Sc', 'Sc', 'RS', 'PS', 'Cr', 'Pa', 'RS', 'Pa', 'PS', 'Pa', 'RS', 'PS', 'PS', 'Pa', 'Pa', 'Sc', 'Sc', 'Sc', 'RS', 'Sc', 'PS', 'Pa', 'Pa', 'Sc', 'Sc', 'Sc', 'Pa', 'Cr', 'RS', 'Pa', 'Cr', 'PS', 'Pa', 'Cr', 'Cr', 'RS', 'Sc', 'Pa', 'Sc', 'Pa', 'Cr', 'Pa', 'RS', 'Pa', 'Sc', 'Cr', 'PS', 'Sc', 'Cr', 'Cr', 'Cr', 'Pa', 'PS', 'Cr', 'Pa', 'Cr', 'RS', 'Sc', 'Cr', 'Cr', 'PS', 'Sc', 'Sc', 'RS', 'RS', 'Pa', 'Sc', 'RS', 'RS', 'RS', 'Cr', 'Sc', 'RS', 'PS', 'Sc', 'Sc', 'Sc', 'PS', 'PS', 'RS', 'Pa', 'RS', 'PS', 'PS', 'Sc', 'Cr', 'PS', 'RS', 'Cr', 'Cr', 'PS', 'Sc', 'Sc', 'Cr', 'Pa', 'PS', 'Sc', 'Cr', 'PS', 'RS', 'Pa', 'Pa', 'Cr', 'RS', 'RS', 'Pa', 'RS', 'Pa', 'PS', 'PS', 'RS', 'Cr', 'Cr', 'RS', 'Sc', 'Cr', 'PS', 'Sc', 'PS', 'Pa', 'PS', 'Sc', 'RS', 'RS', 'PS', 'Cr', 'Cr', 'Sc', 'RS', 'PS', 'RS', 'PS', 'Pa', 'PS', 'Pa', 'Cr', 'Sc', 'PS', 'Cr', 'RS', 'PS', 'PS', 'RS', 'Pa', 'Pa', 'Cr', 'Pa', 'RS', 'Cr', 'Sc', 'Sc', 'PS', 'Cr', 'Cr', 'Sc', 'Cr', 'PS', 'Cr', 'Cr', 'Pa', 'PS', 'Sc', 'Cr', 'Cr', 'RS', 'Cr', 'RS', 'Sc', 'Pa', 'Pa', 'Sc', 'PS', 'PS', 'PS', 'RS', 'Cr', 'PS', 'RS', 'Cr', 'Cr', 'RS', 'PS', 'Cr', 'PS', 'RS', 'Cr', 'Pa', 'RS', 'PS', 'Pa', 'Sc', 'Pa', 'Sc', 'PS', 'RS', 'PS', 'Sc', 'RS', 'Cr', 'Pa', 'Sc', 'PS', 'PS', 'RS', 'Sc', 'RS', 'Cr', 'Sc', 'PS', 'Sc', 'PS', 'RS', 'RS', 'Cr', 'Sc', 'Sc', 'RS', 'Pa', 'Pa', 'Pa', 'Sc', 'Sc', 'PS', 'RS', 'Cr', 'Pa', 'Cr', 'Pa', 'RS', 'PS', 'Sc', 'Pa', 'Cr', 'RS', 'Pa', 'Sc', 'Pa', 'Sc', 'Pa', 'Sc', 'Pa', 'Pa', 'PS', 'Sc', 'Pa', 'Sc', 'Sc', 'RS', 'Pa', 'Cr', 'PS', 'Sc', 'Sc', 'RS', 'RS', 'Pa', 'PS', 'Cr', 'Cr', 'RS', 'Sc', 'PS', 'Cr', 'PS', 'PS', 'Sc', 'Sc', 'PS', 'Sc', 'Sc', 'Pa', 'PS', 'Sc', 'Cr', 'Cr', 'Pa', 'PS', 'Cr', 'Sc', 'RS', 'PS', 'RS', 'Sc', 'Cr', 'Cr', 'Cr', 'Cr', 'Pa', 'Cr', 'Sc', 'Pa', 'RS', 'PS', 'PS', 'RS', 'PS', 'Cr', 'Sc', 'PS', 'RS', 'PS', 'Cr', 'RS', 'RS', 'Cr', 'Pa', 'Pa', 'PS ...
